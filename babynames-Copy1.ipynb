# %%
import re

text = 'I have an email embedded hkan-tshri@gmail.comere. Still hung upbcd@ymail.comthat this can actuallyy happenwow@groupmail.com'
matches = re.findall(r'[\w.-]+@[\w]+.com', text)

if match:
    for match in matches:
     print(match)
else:
    print('not found')
# Out:
# hkan-tshri@gmail.com
# upbcd@ymail.com
# happenwow@groupmail.com

# %%
# Out:
#   File "<ipython-input-74-6ea3a7c37725>", line 1
#     python setup.py install
#                ^
# SyntaxError: invalid syntax

# %%
# Out:
# a sucka
# of sucker
# they sucked

# %%
import sys
import re

def extract_names(filename):
  f = open('C:\\Users\\kantshribaronia\\Downloads\\google-python-exercises\\google-python-exercises\\babynames\\'+filename+'.html', 'r')
  text = f.read()
  #print(text)
  final=[]
  temp_dict = {}
  findingyear = re.search(r'Popularity\sin\s(\d\d\d\d)', text)
  year = findingyear.group(1)
  final.append(year)
  scraping = re.findall(r'<td>(\d+)</td><td>(\w+)</td><td>(\w+)</td>',text)
  #print(scraping)= scraping is a list
  for each in scraping:
    (rank, boyname, girlname) = each
    if boyname not in temp_dict:
      #print(boyname)
      temp_dict[boyname] = rank
    if girlname not in temp_dict:
      temp_dict[girlname] = rank
  #print(temp_dict)
  sorted_values = sorted(temp_dict.keys())
  #print(sorted_values)
  for each in sorted_values:
        final.append(each+" "+temp_dict[each])
  print(final)
  return


def main():
  args = ['baby1990','baby1992','baby1994','baby1996','baby1998','baby2000']

  if not args:
   # print ('usage: [--summaryfile] file [file ...]')
    sys.exit(1)

  # Notice the summary flag and remove it from args if it is present.
  summary = False
  if args[0] == '--summaryfile':
    summary = True
    del args[0]
    
  for filename in args:
    names = extract_names(filename)
  
  # For each filename, get the names, then either print the text output
  # or write it to a summary file
  
if __name__ == '__main__':
  main()
# Out:
# ['1990', 'Aaron 34', 'Abbey 482', 'Abbie 685', 'Abby 222', 'Abdul 934', 'Abel 384', 'Abigail 90', 'Abraham 246', 'Abram 920', 'Adam 32', 'Adan 548', 'Addison 645', 'Adolfo 649', 'Adrian 94', 'Adriana 144', 'Adrianna 325', 'Adrianne 783', 'Adrienne 233', 'Agustin 627', 'Ahmad 562', 'Ahmed 721', 'Aidan 889', 'Aileen 851', 'Aimee 272', 'Aisha 568', 'Aja 940', 'Akeem 405', 'Alaina 441', 'Alan 125', 'Alana 368', 'Alanna 474', 'Alannah 936', 'Albert 167', 'Alberto 225', 'Alden 949', 'Aldo 792', 'Alec 271', 'Alecia 678', 'Alejandra 211', 'Alejandro 126', 'Alesha 695', 'Alessandra 829', 'Alex 59', 'Alexa 146', 'Alexander 28', 'Alexandra 37', 'Alexandre 950', 'Alexandrea 653', 'Alexandria 95', 'Alexandro 837', 'Alexia 557', 'Alexis 66', 'Alfonso 423', 'Alfred 364', 'Alfredo 272', 'Ali 474', 'Alice 347', 'Alicia 53', 'Alina 664', 'Alisa 460', 'Alisha 135', 'Alison 133', 'Alissa 276', 'Allan 382', 'Allen 141', 'Allie 579', 'Allison 48', 'Allyson 236', 'Allyssa 709', 'Alma 386', 'Alonso 805', 'A
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4ec90196538b> in <module>()
# ----> 1 print(scraping)
#
# NameError: name 'scraping' is not defined
